# %%
import pandas as pd

columns = columns = [
    'age', 'workclass', 'fnlwgt', 'education', 'education-num',
    'marital-status', 'occupation', 'relationship', 'race', 'sex',
    'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'
]

dataframe = pd.read_csv('adult.test', names=columns)

# Remove the first row
dataframe = dataframe.iloc[1:]
dataframe
# Out:
#       age      workclass    fnlwgt      education  education-num  \
# 1      25        Private  226802.0           11th            7.0
# 2      38        Private   89814.0        HS-grad            9.0
# 3      28      Local-gov  336951.0     Assoc-acdm           12.0
# 4      44        Private  160323.0   Some-college           10.0
# 5      18              ?  103497.0   Some-college           10.0
# ...    ..            ...       ...            ...            ...
# 16277  39        Private  215419.0      Bachelors           13.0
# 16278  64              ?  321403.0        HS-grad            9.0
# 16279  38        Private  374983.0      Bachelors           13.0
# 16280  44        Private   83891.0      Bachelors           13.0
# 16281  35   Self-emp-inc  182148.0      Bachelors           13.0
#
#             marital-status          occupation     relationship  \
# 1            Never-married   Machine-op-inspct        Own-child
# ...

# %%
dataframe.shape # (16281, 15)

dataframe.columns
dataframe.dtypes
# Out:
# age                object
# workclass          object
# fnlwgt            float64
# education          object
# education-num     float64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capital-gain      float64
# capital-loss      float64
# hours-per-week    float64
# native-country     object
# income             object
# dtype: object

# %%
dataframe.describe()
# Out:
#              fnlwgt  education-num  capital-gain  capital-loss  hours-per-week
# count  1.628100e+04   16281.000000  16281.000000  16281.000000    16281.000000
# mean   1.894357e+05      10.072907   1081.905104     87.899269       40.392236
# std    1.057149e+05       2.567545   7583.935968    403.105286       12.479332
# min    1.349200e+04       1.000000      0.000000      0.000000        1.000000
# 25%    1.167360e+05       9.000000      0.000000      0.000000       40.000000
# 50%    1.778310e+05      10.000000      0.000000      0.000000       40.000000
# 75%    2.383840e+05      12.000000      0.000000      0.000000       45.000000
# max    1.490400e+06      16.000000  99999.000000   3770.000000       99.000000

# %%
dataframe.isnull().sum()

dataframe.isna().sum()

dataframe.duplicated().sum()
dataframe[dataframe.duplicated(keep=False)]
# Out:
#       age      workclass    fnlwgt   education  education-num  \
# 489    24        Private  194630.0   Bachelors           13.0
# 865    24        Private  194630.0   Bachelors           13.0
# 1320   37        Private   52870.0   Bachelors           13.0
# 3901   18   Self-emp-inc  378036.0        12th            8.0
# 7022   30        Private  180317.0   Assoc-voc           11.0
# 9250   29        Private   36440.0   Bachelors           13.0
# 11190  37        Private   52870.0   Bachelors           13.0
# 11213  29        Private   36440.0   Bachelors           13.0
# 13849  30        Private  180317.0   Assoc-voc           11.0
# 15961  18   Self-emp-inc  378036.0        12th            8.0
#
#             marital-status          occupation    relationship    race  \
# 489          Never-married      Prof-specialty   Not-in-family   White
# 865          Never-married      Prof-specialty   Not-in-family   White
# ...

# %%
# Check for empty string ("") in any of the columns
empty_string_mask = (dataframe == "")

# Print the columns and rows where empty strings are found
if empty_string_mask.any().any():
    print("Empty string found in the dataset:")
    print(empty_string_mask.sum())  # Print number of empty strings in each column
    print("Rows with empty strings:")
    print(dataframe[empty_string_mask.any(axis=1)])  # Print rows containing empty strings
else:
    print("No empty strings found in the dataset.")
# Out:
# No empty strings found in the dataset.

# %%
features_numerical = dataframe.select_dtypes(include=['int64', 'float64'])
features_numerical.columns
# Out:
# Index(['fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')

# %%
features_categorical = dataframe.select_dtypes(include=['object'])
features_categorical.columns
# Out:
# Index(['age', 'workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'income'],
#       dtype='object')

# %%
# Histograms for numerical features

import matplotlib.pyplot as plt

features_numerical.hist(figsize=(10, 10))
plt.show()

# %%
import seaborn as sns

fig, axes = plt.subplots(10, 1, figsize=(20, 15))
for i, col in enumerate(features_categorical):
    sns.countplot(x=col, data=features_categorical, ax=axes[i])
plt.subplots_adjust(hspace=1)

# %%
# Show unique values for column 'age'

dataframe['age'].unique()

# convert 'age' to int
dataframe['age'] = dataframe['age'].astype(int)

# Remove age from features_categorical
features_categorical = features_categorical.drop(columns=['age'], axis=1)

# Add 'age' to features_numerical
features_numerical['age'] = dataframe['age']

# %%
# Replace `?` with `undefined` in dataframe
dataframe = dataframe.replace(' ?', 'undefined')

# Show how many columns have `?` in the dataframe
for col in features_categorical.columns.to_list():
    print(f'{col}: {dataframe[col].str.contains("\?").sum()}')
# Out:
# workclass: 0
# education: 0
# marital-status: 0
# occupation: 0
# relationship: 0
# race: 0
# sex: 0
# native-country: 0
# income: 0
# <>:6: SyntaxWarning: invalid escape sequence '\?'
# <>:6: SyntaxWarning: invalid escape sequence '\?'
# C:\Users\hridi\AppData\Local\Temp\ipykernel_14500\3509164520.py:6: SyntaxWarning: invalid escape sequence '\?'
#   print(f'{col}: {dataframe[col].str.contains("\?").sum()}')

# %%
# Replace `undefined` with the most frequent value in each column or mode

for col in features_categorical.columns.to_list():
    dataframe[col] = dataframe[col].replace('undefined', dataframe[col].mode()[0])

# Show unique values for each categorical column
for col in features_categorical.columns.to_list():
    print(f'{col}: {dataframe[col].unique()}')
# Out:
# workclass: [' Private' ' Local-gov' ' Self-emp-not-inc' ' Federal-gov' ' State-gov'
#  ' Self-emp-inc' ' Without-pay' ' Never-worked']
# education: [' 11th' ' HS-grad' ' Assoc-acdm' ' Some-college' ' 10th' ' Prof-school'
#  ' 7th-8th' ' Bachelors' ' Masters' ' Doctorate' ' 5th-6th' ' Assoc-voc'
#  ' 9th' ' 12th' ' 1st-4th' ' Preschool']
# marital-status: [' Never-married' ' Married-civ-spouse' ' Widowed' ' Divorced'
#  ' Separated' ' Married-spouse-absent' ' Married-AF-spouse']
# occupation: [' Machine-op-inspct' ' Farming-fishing' ' Protective-serv'
#  ' Prof-specialty' ' Other-service' ' Craft-repair' ' Adm-clerical'
#  ' Exec-managerial' ' Tech-support' ' Sales' ' Priv-house-serv'
#  ' Transport-moving' ' Handlers-cleaners' ' Armed-Forces']
# relationship: [' Own-child' ' Husband' ' Not-in-family' ' Unmarried' ' Wife'
#  ' Other-relative']
# race: [' Black' ' White' ' Asian-Pac-Islander' ' Other' ' Amer-Indian-Eskimo']
# sex: [' Male' ' Female']
# ...

# %%
features = dataframe.drop(columns='income')
target = dataframe['income']

from sklearn.preprocessing import StandardScaler, OneHotEncoder

target = pd.get_dummies(target, drop_first=True)

# One-hot encode the categorical features

features = pd.get_dummies(features, columns=['sex'], drop_first=True)
features_categorical.drop(['sex', 'income'], axis=1, inplace=True)
features = pd.get_dummies(features, columns=features_categorical.columns.to_list()).astype('int64')

features
# Out:
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 1       25  226802              7             0             0              40
# 2       38   89814              9             0             0              50
# 3       28  336951             12             0             0              40
# 4       44  160323             10          7688             0              40
# 5       18  103497             10             0             0              30
# ...    ...     ...            ...           ...           ...             ...
# 16277   39  215419             13             0             0              36
# 16278   64  321403              9             0             0              40
# 16279   38  374983             13             0             0              50
# 16280   44   83891             13          5455             0              40
# 16281   35  182148             13             0             0              60
#
# ...

# %%
# Create a column native-country_ Holand-Netherlands' with all values 0
features['native-country_ Holand-Netherlands'] = 0
features
# Out:
#        age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 1       25  226802              7             0             0              40
# 2       38   89814              9             0             0              50
# 3       28  336951             12             0             0              40
# 4       44  160323             10          7688             0              40
# 5       18  103497             10             0             0              30
# ...    ...     ...            ...           ...           ...             ...
# 16277   39  215419             13             0             0              36
# 16278   64  321403              9             0             0              40
# 16279   38  374983             13             0             0              50
# 16280   44   83891             13          5455             0              40
# 16281   35  182148             13             0             0              60
#
# ...
